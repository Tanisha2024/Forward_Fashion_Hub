# %%
import pandas as pd

# %%
faq=pd.read_csv("../data/faq.csv")
products=pd.read_csv("../data/products.csv")
print('faq shape',faq.shape)
print('product shape',products.shape)
# Out:
# faq shape (10, 2)
# product shape (20, 10)

# %%
faq.head()
# Out:
#                        question  \
# 0   What is your return policy?
# 1     Can I exchange a product?
# 2  How long does shipping take?
# 3   Do you offer free shipping?
# 4        Can I cancel my order?
#
#                                               answer
# 0  You can return eligible products within 30 day...
# 1  Yes, eligible products can be exchanged for an...
# 2  Standard delivery usually takes 3 to 5 busines...
# 3  Free standard shipping is available on orders ...
# 4  Orders can be cancelled before they are shippe...

# %%
products.head()
# Out:
#   product_id                        name  category  \
# 0       P001  Classic White Cotton Shirt     Shirt
# 1       P002      Black Oversized Hoodie    Hoodie
# 2       P003     Blue Straight Fit Jeans     Jeans
# 3       P004     Beige Wide Leg Trousers  Trousers
# 4       P005         Floral Summer Dress     Dress
#
#                                          description  price   color  \
# 0  Classic regular-fit cotton shirt suitable for ...   1299   White
# 1  Comfortable oversized hoodie with a relaxed fi...   1799   Black
# 2  Classic blue straight-fit jeans suitable for e...   1899    Blue
# 3  Relaxed wide-leg trousers that work well for s...   1699   Beige
# 4  Lightweight floral dress designed for warm wea...   1999  Floral
#
#              size         material         occasion         style
# 0        S|M|L|XL           Cotton   Casual|College       Minimal
# 1        S|M|L|XL     Cotton Blend   Casual|College    Streetwear
# 2  28|30|32|34|36     Cotton Denim   Casual|College       Classic
# 3        S|M|L|XL  Polyester Blend    Casual|Office  Smart Casual
# 4        S|M|L|XL            Rayon  Summer|Vacation      Feminine

# %%
faq.isnull().sum()
# Out:
# question    0
# answer      0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id     0
# name           0
# category       0
# description    0
# price          0
# color          0
# size           0
# material       0
# occasion       0
# style          0
# dtype: int64
